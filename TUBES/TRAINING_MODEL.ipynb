# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaam00/2025_Visi-Komputer_TI-2C/blob/main/TUBES/TRAINING_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Dec 16 13:55:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.6 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# Rempah_Object_Detection.v3i.yolov11.zip  sample_data

# %%
# !unzip /content/Rempah_Object_Detection.v3i.yolov11.zip
# Out:
# Archive:  /content/Rempah_Object_Detection.v3i.yolov11.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/13_jpg.rf.c3385a865428c65311df17951ae5a979.jpg
#  extracting: test/images/1_jpg.rf.7b07b83f387f4c08975b00e960ab1a74.jpg
#  extracting: test/images/5_jpg.rf.97131c59fbc768e2b4be40afed193d21.jpg
#  extracting: test/images/jahe3_jpg.rf.36b5990777c09618c34fb10ff8da2b86.jpg
#  extracting: test/images/jahe4_jpg.rf.63e6beeedd81ea39d12209fca00fe671.jpg
#  extracting: test/images/jahe_8_jpg.rf.a32c873224dda77bfc53a4d9f0f8586e.jpg
#  extracting: test/images/kencur8_jpg.rf.6eee03837651367576d6b6c5d5aa8faa.jpg
#  extracting: test/images/kencur_6_jpg.rf.f92b20c2636f9f189933764eabd66ccf.jpg
#  extracting: test/images/kunyit10_jpg.rf.b892a395437f4fb7b1bc10c1a785879d.jpg
#  extracting: test/images/kunyit8_jpg.rf.eb4a5ce4025bfadff7a2efdad55b5a85.jpg
# ...

# %%
# !ls /content
# Out:
# 'Rempah Object Detection.v2i.yolov11.zip'   runs   sample_data	 yolo11n.pt

# %%
# !yolo detect train \
  data=data.yaml \
  model=yolov8s.pt \
  epochs=200 \
  imgsz=640 \
  batch=16
# Out:
# ...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download("/content/runs/detect/train/weights/best.pt")
